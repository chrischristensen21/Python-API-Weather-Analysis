# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# url
url = "http://api.openweathermap.org/data/2.5/weather?"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 633

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['pisco',
#  'new norfolk',
#  'lazaro cardenas',
#  'tuktoyaktuk',
#  'punta arenas',
#  'saint anthony',
#  'anshun',
#  'bowen',
#  'saldanha',
#  'tsihombe',
#  'bredasdorp',
#  'illoqqortoormiut',
#  'hasaki',
#  'busselton',
#  'jiaojiang',
#  'bluff',
#  'nouadhibou',
#  'olafsvik',
#  'koygorodok',
#  'punta alta',
#  'tasiilaq',
#  'gewane',
#  'cherskiy',
#  'shelburne',
#  'atuona',
#  'flin flon',
#  'yafran',
#  'vaini',
#  'luanda',
#  'ushuaia',
#  'alotau',
#  'longyearbyen',
#  'kapaa',
#  'amderma',
#  'albany',
#  'rocha',
#  'cayenne',
#  'luderitz',
#  'rostaq',
#  'palmer',
#  'gat',
#  'marsaxlokk',
#  'jamestown',
#  'tuggurt',
#  'bengkulu',
#  'yellowknife',
#  'codrington',
#  'springfield',
#  'male',
#  'lata',
#  'faanui',
#  'nokaneng',
#  'fort nelson',
#  'dikson',
#  'naifaru',
#  'rikitea',
#  'vanavara',
#  'sinkat',
#  'saint george',
#  'mataura',
#  'aykhal',
#  'faya',
#  'upernavik',
#  'college',
#  'kherson',
#  'yuncheng',
#  'bethel',
#  'leh',
#  'khatanga',
#  'phan rang',
#  'mahebourg',
#  'buta',
#  'kudahuvadhoo',
#  'ahipara',
#  'jackson',
#  'lola',
#  'east london',
#  'hermanus',
#  'murmashi',
#  'sorland',
#  'nantucket',
#  'nemuro',
#  'batouri',
#  'fairbanks',
#  'coquimbo',
#  'bambous virieux',
#  'batemans bay',
#  'panama city',
#  'saint-philippe',
#  'nguiu',
#  'nikolskoye',
#  'hobart',
#  'mys shmidta',
#  'miquelon',
#  'lorengau',
#  'caramay',
#  'avarua',
#  'kifri',
#  'nogliki',
#  'nepa nagar',
#  'narsaq',
#  'ribeira grande',
#  'solnechnyy',
#  'riyadh',
#  'taolanaro',
#  'finnsnes',
#  'griffith',
#  'sakakah',
#  'hilo',
#  'kloulklubed',
#  'tuatapere',
#  'mackay',
#  'tabou',
#  'gunnedah',
#  'verona',
#  'sorong',
#  'sao filipe',
#  'kochi',
#  'caravelas',
#  'port elizabeth',
#  'vadinsk',
#  'avera',
#  'hithadhoo',
#  'airai',
#  'krasnokamensk',
#  'nova olimpia',
#  'linxia',
#  'samusu',
#  'tumannyy',
#  'qiyang',
#  'huilong',
#  'luau',
#  'paamiut',
#  'castro',
#  'vaitupu',
#  'deputatskiy',
#  'kiama',
#  'puerto ayora',
#  'grenada',
#  'kaitangata',
#  'khonuu',
#  'mar del plata',
#  'makakilo city',
#  'qaanaaq',
#  'saskylakh',
#  'port alfred',
#  'umm lajj',
#  'dali',
#  'butaritari',
#  'newport',
#  'nhulunbuy',
#  'pokanayevka',
#  'gavrilov posad',
#  'bayanday',
#  'geraldton',
#  'fortuna',
#  'barrow',
#  'turukhansk',
#  'derzhavinsk',
#  'klaksvik',
#  'coolum beach',
#  'zhigansk',
#  'winston-salem',
#  'korhogo',
#  'kazalinsk',
#  'cabo san lucas',
#  'guerrero negro',
#  'tiksi',
#  'severo-kurilsk',
#  'belushya guba',
#  'dalby',
#  'olavarria',
#  'kutum',
#  'san patricio',
#  'beian',
#  'stamsund',
#  'kropotkin',
#  'acapulco',
#  'saint-pierre',
#  'tura',
#  'portpatrick',
#  'namibe',
#  'norman wells',
#  'yar-sale',
#  'markivka',
#  'barawe',
#  'zhangye',
#  'bawku',
#  'lebu',
#  'mana',
#  'bubaque',
#  'vao',
#  'talnakh',
#  'nuuk',
#  'jalu',
#  'mangan',
#  'clyde river',
#  'shingu',
#  'marzuq',
#  'arraial do cabo',
#  'kavaratti',
#  'vanimo',
#  'half moon bay',
#  'te anau',
#  'barentsburg',
#  'souillac',
#  'pevek',
#  'tomatlan',
#  'caborca',
#  'wulanhaote',
#  'coihaique',
#  'sur',
#  'shalinskoye',
#  'torbay',
#  'hay river',
#  'balkhash',
#  'pyaozerskiy',
#  'puerto colombia',
#  'lakshmipur',
#  'hokitika',
#  'arlit',
#  'salamiyah',
#  'kuching',
#  'ketou',
#  'lyman',
#  'kostomuksha',
#  'karratha',
#  'georgetown',
#  'port hawkesbury',
#  'oksfjord',
#  'nizhneyansk',
#  'palaikastron',
#  'chulman',
#  'zeya',
#  'ventspils',
#  'escanaba',
#  'victoria',
#  'pelym',
#  'port-cartier',
#  'anadyr',
#  'constitucion',
#  'tarakan',
#  'pierre',
#  'qaqortoq',
#  'esperance',
#  'hualmay',
#  'murray bridge',
#  'hauterive',
#  'katsuura',
#  'sanmenxia',
#  'mosterhamn',
#  'brigantine',
#  'prince rupert',
#  'monteiro',
#  'padang',
#  'sayyan',
#  'ostrovnoy',
#  'buluang',
#  'ilulissat',
#  'marrakesh',
#  'salinas',
#  'oistins',
#  'sharjah',
#  'portland',
#  'tiznit',
#  'tual',
#  'mendahara',
#  'vostok',
#  'port lincoln',
#  'trincomalee',
#  'aklavik',
#  'temirtau',
#  'carnarvon',
#  'alta floresta',
#  'mahajanga',
#  'quatre cocos',
#  'merced',
#  'vallenar',
#  'warrnambool',
#  'broken hill',
#  'chestermere',
#  'tecolutla',
#  'kenai',
#  'carutapera',
#  'salalah',
#  'viedma',
#  'igrim',
#  'wasilla',
#  'havelock',
#  'krasnousolskiy',
#  'acajutla',
#  'beringovskiy',
#  'xique-xique',
#  'lavrentiya',
#  'ancud',
#  'waterloo',
#  'burica',
#  'forrest city',
#  'konstantinovka',
#  'florianopolis',
#  'karkaralinsk',
#  'santa maria',
#  'la ronge',
#  'pachperwa',
#  'yelizovo',
#  'hervey bay',
#  'muscat',
#  'bognor regis',
#  'mnogovershinnyy',
#  'lapi',
#  'gurgan',
#  'menongue',
#  'kano',
#  'iqaluit',
#  'aden',
#  'doka',
#  'simao',
#  'nortelandia',
#  'sinop',
#  'wanning',
#  'daru',
#  'acari',
#  'itoman',
#  'hobyo',
#  'kalmunai',
#  'flinders',
#  'vardo',
#  'amahai',
#  'leningradskiy',
#  'chernyshevskiy',
#  'la libertad',
#  'kupang',
#  'san quintin',
#  'gucheng',
#  'crestview',
#  'benguela',
#  'gurh',
#  'haines junction',
#  'hami',
#  'atbasar',
#  'kodiak',
#  'egvekinot',
#  'livingston',
#  'novyy yarychiv',
#  'gravelbourg',
#  'maceio',
#  'cedartown',
#  'pachino',
#  'rungata',
#  'seoul',
#  'pacifica',
#  'kavieng',
#  'puerto ayacucho',
#  'rouvroy',
#  'ponta do sol',
#  'rock sound',
#  'inhambane',
#  'cap malheureux',
#  'eureka',
#  'cuamba',
#  'kabinda',
#  'dingle',
#  'malmo',
#  'nisia floresta',
#  'vila velha',
#  'richards bay',
#  'naryan-mar',
#  'sola',
#  'port hardy',
#  'dzhebariki-khaya',
#  'fene',
#  'ukiah',
#  'yamada',
#  'myrtle beach',
#  'tessalit',
#  'buala',
#  'cedar city',
#  'lahaina',
#  'tabiauea',
#  'chajul',
#  'vaitape',
#  'vilyuysk',
#  'mbaiki',
#  'inhapim',
#  'lakes entrance',
#  'nabire',
#  'ginir',
#  'husavik',
#  'lompoc',
#  'itaituba',
#  'angoche',
#  'kapit',
#  'soma',
#  'sorvag',
#  'kahului',
#  'valley city',
#  'miranda',
#  'bouna',
#  'santiago de cao',
#  'akhmim',
#  'hamilton',
#  'rypefjord',
#  'altay',
#  'bathsheba',
#  'grand centre',
#  'babu',
#  'yulara',
#  'maisuru',
#  'petropavlovsk-kamchatskiy',
#  'saleaula',
#  'tiruchchendur',
#  'hofn',
#  'alipur',
#  'ashtabula',
#  'sokolo',
#  'navapur',
#  'thompson',
#  'mgandu',
#  'tambovka',
#  'mandla',
#  'carroll',
#  'sarangani',
#  'dakar',
#  'boleslawiec',
#  'hinton',
#  'denpasar',
#  'mayumba',
#  'aanekoski',
#  'halalo',
#  'trofors',
#  'bonavista',
#  'semnan',
#  'teahupoo',
#  'moranbah',
#  'gallup',
#  'saint-francois',
#  'kilimatinde',
#  'hirara',
#  'dalbandin',
#  'tamiahua',
#  'upington',
#  'gualeguaychu',
#  'morondava',
#  'lagoa',
#  'chuy',
#  'malwan',
#  'cape town',
#  'baberu',
#  'baikunthpur',
#  'virginia beach',
#  'paita',
#  'broome',
#  'blackfoot',
#  'sitka',
#  'maracas',
#  'suda',
#  'araguacu',
#  'rio grande',
#  'gashua',
#  'tuy hoa',
#  'sinnamary',
#  'fetesti',
#  'provideniya',
#  'vila franca do campo',
#  'asekeyevo',
#  'sehithwa',
#  'bilibino',
#  'newtownards',
#  'longlac',
#  'meulaboh',
#  'galiwinku',
#  'qandahar',
#  'ifakara',
#  'camacupa',
#  'san vicente',
#  'vestmanna',
#  'narasannapeta',
#  'marfino',
#  'balkanabat',
#  'suchedniow',
#  'laguna',
#  'fallon',
#  'honiara',
#  'salinopolis',
#  'mandan',
#  'vama buzaului',
#  'rawatsar',
#  'sitio novo do tocantins',
#  'santiago',
#  'yei',
#  'qasigiannguit',
#  'mayo',
#  'baykit',
#  'santos dumont',
#  'pundaguitan',
#  'concarneau',
#  'kiunga',
#  'andenes',
#  'chokurdakh',
#  'kudat',
#  'nizhniy ingash',
#  'cranbrook',
#  'cirebon',
#  'koslan',
#  'healesville',
#  'port hedland',
#  'skibbereen',
#  'sao joao da barra',
#  'grand-lahou',
#  'betong',
#  'port keats',
#  'southbridge',
#  'svetlogorsk',
#  'marawi',
#  'sechura',
#  'port blair',
#  'sampit',
#  'yoichi',
#  'kenora',
#  'san cristobal',
#  'noumea',
#  'korgen',
#  'kaeo',
#  'grand gaube',
#  'apatou',
#  'mitsamiouli',
#  'krasnyy chikoy',
#  'numan',
#  'ovsyanka',
#  'bellmead',
#  'matay',
#  'manta',
#  'puerto quijarro',
#  'merauke',
#  'baisha',
#  'ust-nera',
#  'tres lagoas',
#  'meadow lake',
#  'zatoka',
#  'kijang',
#  'viligili',
#  'mokshan',
#  'talcahuano',
#  'crotone',
#  'belyy yar',
#  'kholtoson',
#  'ulagan',
#  'tabon',
#  'fort saint james',
#  'tautira',
#  'shimoda',
#  'muros',
#  'beberibe',
#  'filadelfia',
#  'alofi',
#  'gamboma',
#  'comodoro rivadavia',
#  'zalantun',
#  'cidreira',
#  'west bay',
#  'mrirt',
#  'sioux lookout',
#  'ballina',
#  'nuoro',
#  'akcaabat',
#  'ust-kuyga',
#  'mirnyy',
#  'manadhoo',
#  'siwani',
#  'conceicao da barra',
#  'evensk',
#  'taoudenni',
#  'verkhnevilyuysk',
#  'keelung',
#  'tekirdag',
#  'batavia',
#  'zyryanka',
#  'amealco',
#  'kintampo',
#  'floro',
#  'satitoa',
#  'lerwick',
#  'yangambi',
#  'bilma',
#  'batagay',
#  'rio gallegos',
#  'caiaponia',
#  'kovdor',
#  'mehamn',
#  'irkutsk',
#  'grand river south east',
#  'bogande',
#  'urdzhar',
#  'racine',
#  'jadu',
#  'los llanos de aridane',
#  'oriximina',
#  'pangoa',
#  'pinega',
#  'maniitsoq',
#  'kieta',
#  'anar darreh',
#  'houma',
#  'lolua',
#  'athieme',
#  'antakya',
#  'palabuhanratu',
#  'kindu',
#  'scituate',
#  'nikolayevsk-na-amure',
#  'ust-tsilma',
#  'madang',
#  'galle',
#  'toliary',
#  'trairi',
#  'along',
#  'kanigoro',
#  'pont-a-mousson',
#  'cockburn town',
#  'birjand',
#  'chapais',
#  'havre',
#  'mount gambier',
#  'ko samui',
#  'zunyi',
#  'vastervik',
#  'chifeng',
#  'douglas',
#  'bijie',
#  'lahat',
#  'mahuva',
#  'palm bay',
#  'mitu']

# %%
# set up list to hold two different temperatures
dates = []
longitudes = []
latitudes = []
names = []
countries = []
temperatures = []
clouds = []
wind_speeds = []
humidities = []


# loop throught the list of units and append them to temperatures list
for city in cities:
    try:
        query_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=imperial"

        # Get weather data
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()

        date = weather_json["dt"]
        dates.append(date)
        
        longitude = weather_json["coord"]["lon"]
        longitudes.append(longitude)
        
        latitude = weather_json["coord"]["lat"]
        latitudes.append(latitude) 
        
        name = weather_json["name"]
        names.append(name)
        
        country = weather_json["sys"]["country"]
        countries.append(country) 
        
        temperature = weather_json["main"]["temp"]
        temperatures.append(temperature)
        
        cloud = weather_json["clouds"]["all"]
        clouds.append(cloud)
        
        wind_speed = weather_json["wind"]["speed"]
        wind_speeds.append(wind_speed) 
        
        humidity = weather_json["main"]["humidity"]
        humidities.append(humidity) 
        
    except:
        pass

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"Date": dates,
                           "Longitude": longitudes,
                           "Latitude": latitudes,
                           "City": names,
                           "Country": countries,
                           "Temperature": temperatures,
                           "% Cloudiness": clouds,
                           "Wind Speed": wind_speeds,
                           "% Humidity": humidities 
                          })
weather_df
# Out:
#            Date  Longitude  Latitude             City Country  Temperature  \
# 0    1637973176   -76.2167  -13.7000            Pisco      PE        66.25
# 1    1637973176   147.0587  -42.7826      New Norfolk      AU        58.50
# 2    1637973177  -102.2000   17.9583  Lázaro Cárdenas      MX        78.44
# 3    1637973177  -133.0374   69.4541      Tuktoyaktuk      CA        -2.20
# 4    1637973177   -70.9167  -53.1500     Punta Arenas      CL        48.31
# ..          ...        ...       ...              ...     ...          ...
# 574  1637973307   105.2942   27.3125            Bijie      CN        42.66
# 575  1637973458   103.5333   -3.8000            Lahat      ID        76.15
# 576  1637973458    71.7622   21.0914           Mahuva      IN        75.24
# 577  1637973459   -80.5887   28.0345         Palm Bay      US        68.63
# 578  1637973459   -70.1733    1.1983             Mitú      CO        76.82
#
#      % Cloudiness  Wind Speed  % Humidity
# 0               0       13.80          82
# 1              88        2.51          40
# 2              40        3.47          77
# 3              90       21.85          84
# 4              75       19.57          66
# ..            ...         ...         ...
# 574           100        1.25          81
# 575            99        1.57          93
# 576            93        5.97          46
# 577            90        4.61          68
# 578           100        2.46          83
#
# [579 rows x 9 columns]

# %%
weather_df.to_csv("weather.csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_csv = pd.read_csv('weather.csv')
weather_csv
# Out:
#            Date  Longitude  Latitude             City Country  Temperature  \
# 0    1637973176   -76.2167  -13.7000            Pisco      PE        66.25
# 1    1637973176   147.0587  -42.7826      New Norfolk      AU        58.50
# 2    1637973177  -102.2000   17.9583  Lázaro Cárdenas      MX        78.44
# 3    1637973177  -133.0374   69.4541      Tuktoyaktuk      CA        -2.20
# 4    1637973177   -70.9167  -53.1500     Punta Arenas      CL        48.31
# ..          ...        ...       ...              ...     ...          ...
# 574  1637973307   105.2942   27.3125            Bijie      CN        42.66
# 575  1637973458   103.5333   -3.8000            Lahat      ID        76.15
# 576  1637973458    71.7622   21.0914           Mahuva      IN        75.24
# 577  1637973459   -80.5887   28.0345         Palm Bay      US        68.63
# 578  1637973459   -70.1733    1.1983             Mitú      CO        76.82
#
#      % Cloudiness  Wind Speed  % Humidity
# 0               0       13.80          82
# 1              88        2.51          40
# 2              40        3.47          77
# 3              90       21.85          84
# 4              75       19.57          66
# ..            ...         ...         ...
# 574           100        1.25          81
# 575            99        1.57          93
# 576            93        5.97          46
# 577            90        4.61          68
# 578           100        2.46          83
#
# [579 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
hum100 = weather_csv.loc[weather_csv['% Humidity'] > 100, ['% Humidity']]
hum100
# Out:
# Empty DataFrame
# Columns: [% Humidity]
# Index: []

# %%
#No Cities > 100% Humidity

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_csv["Latitude"], weather_csv["Temperature"])
plt.title('Latitude vs. Temperature Plot')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.savefig('Latitude vs. Temperature Plot.png')
plt.show()

# %% [markdown]
# Scatter plot of latitude vs temperature of each location

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_csv["Latitude"], weather_csv["% Humidity"])
plt.title('Latitude vs. Humidity Plot')
plt.xlabel('Latitude')
plt.ylabel('% Humidity')
plt.savefig('Latitude vs. Humidity Plot.png')
plt.show()

# %%
Scatter plot of latitude vs humidity of each location

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_csv["Latitude"], weather_csv["% Cloudiness"])
plt.title('Latitude vs. Cloudiness Plot')
plt.xlabel('Latitude')
plt.ylabel('% Cloudiness')
plt.savefig('Latitude vs. Cloudiness Plot.png')
plt.show()

# %%
Scatter plot of latitude vs cloudiness of each location

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_csv["Latitude"], weather_csv["Wind Speed"])
plt.title('Latitude vs. Wind Speed Plot')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('Latitude vs. Wind Speed Plot.png')
plt.show()

# %%
Scatter plot of latitude vs wind speed of each location

# %% [markdown]
# ## Linear Regression

# %%
north_hem = weather_csv.loc[weather_csv['Latitude'] > 0]
south_hem = weather_csv.loc[weather_csv['Latitude'] < 0]

# %%
north_hem
# Out:
#            Date  Longitude  Latitude             City Country  Temperature  \
# 2    1637973177  -102.2000   17.9583  Lázaro Cárdenas      MX        78.44
# 3    1637973177  -133.0374   69.4541      Tuktoyaktuk      CA        -2.20
# 5    1637973014   -93.2180   45.0205    Saint Anthony      US        33.35
# 6    1637973178   105.9333   26.2500           Anshun      CN        45.55
# 10   1637973180   140.8333   35.7333           Hasaki      JP        50.40
# ..          ...        ...       ...              ...     ...          ...
# 573  1637973388   -96.1670   41.3000          Douglas      US        45.64
# 574  1637973307   105.2942   27.3125            Bijie      CN        42.66
# 576  1637973458    71.7622   21.0914           Mahuva      IN        75.24
# 577  1637973459   -80.5887   28.0345         Palm Bay      US        68.63
# 578  1637973459   -70.1733    1.1983             Mitú      CO        76.82
#
#      % Cloudiness  Wind Speed  % Humidity
# 2              40        3.47          77
# 3              90       21.85          84
# 5              75        8.05          39
# 6             100        4.54          77
# 10              6       16.17          46
# ..            ...         ...         ...
# 573             1        0.00          48
# 574           100        1.25          81
# 576            93        5.97          46
# 577            90        4.61          68
# 578           100        2.46          83
#
# [405 rows x 9 columns]

# %%
south_hem
# Out:
#            Date  Longitude  Latitude           City Country  Temperature  \
# 0    1637973176   -76.2167  -13.7000          Pisco      PE        66.25
# 1    1637973176   147.0587  -42.7826    New Norfolk      AU        58.50
# 4    1637973177   -70.9167  -53.1500   Punta Arenas      CL        48.31
# 7    1637973178   148.2333  -20.0167          Bowen      AU        84.42
# 8    1637973179    17.9442  -33.0117       Saldanha      ZA        60.85
# ..          ...        ...       ...            ...     ...          ...
# 559  1637973452   145.7966   -5.2246         Madang      PG        85.60
# 561  1637973164   -39.2689   -3.2778         Trairi      BR        80.53
# 563  1637973453   112.2190   -8.1300       Kanigoro      ID        81.12
# 569  1637973456   140.7667  -37.8333  Mount Gambier      AU        64.31
# 575  1637973458   103.5333   -3.8000          Lahat      ID        76.15
#
#      % Cloudiness  Wind Speed  % Humidity
# 0               0       13.80          82
# 1              88        2.51          40
# 4              75       19.57          66
# 7             100        7.63          68
# 8              11       15.17          93
# ..            ...         ...         ...
# 559            47        2.77          68
# 561             0       11.34          78
# 563            99        6.49          78
# 569            40       19.57          45
# 575            99        1.57          93
#
# [174 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = north_hem["Temperature"]
y_values = north_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(35,80),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(35,70),fontsize=14,color="blue")
plt.title('Northern Hemisphere Temperature vs. Latitude Linear Regression')
plt.xlabel('Temperature (°F)')
plt.ylabel('Latitude')
plt.savefig('Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# There is a fairly strong correlation between the temperature and latitudes of the northern hemisphere as was expected. The temperatures tend to increase the closer you get to the equator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = south_hem["Temperature"]
y_values = south_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(65,-45),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(65,-50),fontsize=14,color="blue")
plt.title('Southern Hemisphere Temperature vs. Latitude Linear Regression')
plt.xlabel('Temperature (°F)')
plt.ylabel('Latitude')
plt.savefig('Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# There is also a fairly strong correlation between the temperature and latitudes of the southern hemisphere as was expected. However the R-Squared is not quite as strong but looking at the plot, it is clear that the temperatures trend warmer the closer you approach the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_hem["% Humidity"]
y_values = north_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,77),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(15,70),fontsize=14,color="blue")
plt.title('Northern Hemisphere Humidity vs. Latitude Linear Regression')
plt.xlabel('Humidity (%)')
plt.ylabel('Latitude')
plt.savefig('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# There does not appear to be much correlation between humidty and latitude of the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_hem["% Humidity"]
y_values = south_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(15,-3),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(15,-8),fontsize=14,color="blue")
plt.title('Southern Hemisphere Humidity vs. Latitude Linear Regression')
plt.xlabel('Humidity (%)')
plt.ylabel('Latitude')
plt.savefig('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# There does not appear to be much correlation between humidty and latitude of the southern hemisphere as was the northern.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_hem["% Cloudiness"]
y_values = north_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,78),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(0,73),fontsize=14,color="blue")
plt.title('Northern Hemisphere Cloudiness vs. Latitude Linear Regression')
plt.xlabel('% Cloudiness')
plt.ylabel('Latitude')
plt.savefig('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# There is a very low correlation between cloudiness and latitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_hem["% Cloudiness"]
y_values = south_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-50),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(0,-55),fontsize=14,color="blue")
plt.title('Southern Hemisphere Cloudiness vs. Latitude Linear Regression')
plt.xlabel('% Cloudiness')
plt.ylabel('Latitude')
plt.savefig('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# There is also a very low correlation between cloudiness and latitude in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_hem["Wind Speed"]
y_values = north_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(25,76),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(25,69),fontsize=14,color="blue")
plt.title('Norhtern Hemisphere Wind Speed vs. Latitude Linear Regression')
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.savefig('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# Wind speed and latitude show little to know correlation in the northen hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_hem["Wind Speed"]
y_values = south_hem["Latitude"]
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
rvalue = rvalue**2
rvaluer = rvalue.round(2)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(19,-5),fontsize=14,color="red")
plt.annotate((f'R-Squared = {rvaluer}'),(19,-10),fontsize=14,color="blue")
plt.title('Southern Hemisphere Wind Speed vs. Latitude Linear Regression')
plt.xlabel('Wind Speed (mph)')
plt.ylabel('Latitude')
plt.savefig('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png')
plt.show()

# %% [markdown]
# Wind speed and latitude show little to know correlation in the southern hemisphere as well.
